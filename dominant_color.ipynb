# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1=cv2.imread('images.jpg')

# %%
img=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
print(img.shape)
img=img.reshape((img.shape[0]*img.shape[1] ,3))
print(img.shape)
# Out:
# (194, 259, 3)
# (50246, 3)

# %%
n_clusters=4
from sklearn.cluster import KMeans
kmeans= KMeans(n_clusters)
kmeans.fit(img)
colors=kmeans.cluster_centers_
labels= kmeans.labels_

# %%
def closest_colour(requested_colour):
    mean_colour={}
    for key, name in webcolors.css3_hex_to_names.items:
        r_c,g_c,b_c=webcolors.hex_to_rgb(key)
        rd = (r_c - requested_colour[0]) ** 2
        gd = (g_c - requested_colour[0]) ** 2
        bd = (b_c - requested_colour[0]) ** 2
        min_colours[(rd+gd+bd)]= name
    return min_colours[min(min_colours.keys())]

def get_colour_name(requested_colour):
    try:
        closest_name=actual_name=webcolors.rgb_to_name(requested_colour)
    except ValueError:
        closest_colour=closest_colour(requested_colour)
        actual_name=None
    return actual_name, closest_name

# %%
label_count = [0 for i in range(n_clusters)]
for ele in labels:
    label_count[ele] += 1
    
index_color = label_count.index(max(label_count))

print
for index,ele in enumerate (label_count):
    print (str(ele) + 'labels with pixel value ->'),
    print(colors[index]),
    print ('percentage ->' + str(float(ele)/len(labels)*100))
    print()
# Out:
# 14877labels with pixel value ->
# [14.3948518  33.56589825 93.08898447]
# percentage ->29.60832703100744
#
# 6683labels with pixel value ->
# [222.1032625  146.83268482   8.42202933]
# percentage ->13.30056123870557
#
# 19537labels with pixel value ->
# [190.69539847  19.73010186  12.50401802]
# percentage ->38.88269713011981
#
# 9149labels with pixel value ->
# [ 27.96982947 108.23677307   6.39199825]
# percentage ->18.208414600167178
